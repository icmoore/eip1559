# %%
# %matplotlib inline
from collections import defaultdict

import matplotlib.pyplot as plt
import numpy as np
import pymc3 as pm
import seaborn as sns
import scipy.stats as st
from theano import shared

plt.style.use('seaborn-darkgrid')

# %%
def invlogit(x):
    return np.exp(x) / (1 + np.exp(x))

def scale_x(x, k, x0, y0):
    return k*(x-x0) + np.log(y0/(1-y0)) 

x0 = 3.5; y0 = 0.8; k = 1.6

# %%
n = 4000
coeff = 1.

predictors = np.random.uniform(0, 10, 100)
predictors_shared = shared(predictors)

x = scale_x(predictors, k, 4, y0)
outcomes = np.random.binomial(1, invlogit(x))

# %%
predictors_out_of_sample = np.random.uniform(2.2,4,30)
x = scale_x(predictors_out_of_sample, k, x0, y0)

outcomes_out_of_sample = np.random.binomial(1, invlogit(x))

# %%
with pm.Model() as model:
    pia = pm.Normal('pia', mu=x0, sigma=1)
    x = scale_x(predictors_shared, k, pia, y0)
    outcome = pm.Bernoulli('outcome', logit_p = x, observed=outcomes)
    trace = pm.sample(500)
    mp = pm.find_MAP(include_transformed=True)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [pia]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:03<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 500 draw iterations (2_000 + 1_000 draws total) took 16 seconds.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 00:00<00:00 logp = -27.219, ||grad|| = 9.1876]
#     </div>

# %%
pm.traceplot(trace);
# Out:
# /Users/nicolle_nordmann/anaconda3/lib/python3.8/site-packages/arviz/data/io_pymc3.py:88: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(

# %%
pia_update = np.mean(trace['pia'])

# %%
predictors_shared.set_value(predictors_out_of_sample)

# %%
ppc = pm.sample_posterior_predictive(trace, model=model, samples=100)
# Out:
# /Users/nicolle_nordmann/anaconda3/lib/python3.8/site-packages/pymc3/sampling.py:1617: UserWarning: samples parameter is smaller than nchains times ndraws, some draws and/or chains may not be represented in the returned posterior predictive sample
#   warnings.warn(
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:00<00:00]
#     </div>

# %%
from matplotlib.ticker import StrMethodFormatter
sns.set()
blue, green, red, purple, gold, teal = sns.color_palette(n_colors=6)
pct_formatter = StrMethodFormatter('{x:.1%}')

# %%
(ppc['outcome'] == 1).sum(axis=0)
# Out:
# array([29, 38, 67, 28, 22, 19, 35, 77, 22, 69, 36, 42, 24, 47, 52, 68, 34,
#        24, 76, 45, 25, 60, 25, 78, 57, 29, 68, 30, 37, 65])

# %%
(ppc['outcome'] == 0).sum(axis=0)
# Out:
# array([71, 62, 33, 72, 78, 81, 65, 23, 78, 31, 64, 58, 76, 53, 48, 32, 66,
#        76, 24, 55, 75, 40, 75, 22, 43, 71, 32, 70, 63, 35])

# %%
fig, ax = plt.subplots(figsize=(12, 8))

β = st.beta((ppc['outcome'] == 1).sum(axis=0), (ppc['outcome'] == 0).sum(axis=0))

# estimated probability
ax.scatter(x=predictors_out_of_sample, y=β.mean())

# error bars on the estimate
plt.vlines(predictors_out_of_sample, *β.interval(0.95))

# actual outcomes
ax.scatter(x=predictors_out_of_sample, y=outcomes_out_of_sample, marker='x')

# True probabilities
x_pia = np.arange(0,7,0.1)
x_pia_belief = scale_x(x_pia, k, x0, y0)
x_pia_update = scale_x(x_pia, k, pia_update, y0)
ax.scatter(x=x0, y=y0, color='red',s=100, label='Initial Guess')
ax.plot(x_pia, invlogit(x_pia_belief), linestyle='--', label='Initial Belief')
ax.plot(x_pia, invlogit(x_pia_update), linestyle='--', label='Update',color='red')
ax.yaxis.set_major_formatter(pct_formatter);
ax.set_xlabel('Block Size [Mb]', fontsize=16)
ax.set_ylabel('Prob Missed Block', fontsize=16);
ax.set_title("Missed Block Curve", fontsize=20);
ax.legend(loc='lower right')

# %%
N = 100000
WIN = 1000

r = bernoulli.rvs(0.01, size=N)
x = np.convolve(r, np.ones(WIN)/WIN, mode='valid') 

t = np.array(range(len(x)))
x = x + 0.1*np.exp(-((t-10000)/200)**2)

fig, ax = plt.subplots(1, 1)
ax.plot(x, label='bernoulli pmf')

# %%
#!pip3 install lifelines

# %%
import pandas as pd
from lifelines import KaplanMeierFitter

# %%
def invlogit(x):
    return np.exp(x) / (1 + np.exp(x))

def scale_x(x, k, x0, y0):
    return k*(x-x0) + np.log(y0/(1-y0)) 

def scale_map(x_pia, k, x0, y0):
    x_pia_belief = scale_x(x_pia, k, x0, y0)
    return 2*(invlogit(x_pia_belief)-0.5)

# %%
data = {'value': r}

km = pd.DataFrame(data)
a = km['value'].shift().eq(0)
b = a.cumsum()
km['new'] = b.sub(b.mask(a).ffill().fillna(0)).astype(int)
df = km.loc[km['value'].values == 1]
df = df.assign(grp = 1)

# %%
kmf = KaplanMeierFitter()

## Fit kmf object to data
kmf.fit(df['new'], event_observed = df['value'])

## Plot KM curve
ax = kmf.plot(xlim=(0, 400), ylim=(0, 1))
#kmf.survival_function_

# %%
p = kmf.predict(df['new'].values)
deltas = 0.1*scale_map(p, k, x0, y0)
df = df.assign(deltas = np.array(deltas))
df = df.assign(exp_deltas = np.exp(df['deltas'].values))

# %%
BASE_BLOCK_SIZE = 10
s = BASE_BLOCK_SIZE*np.ones(len(df))

for k in range(1,len(s)):
    s[k] = s[k-1]*df['exp_deltas'].values[k]
    
df = df.assign(block_size = s)  
df.reset_index(inplace=True)

# %%
df
# Out:
#       index  value  new  grp  deltas  exp_deltas  block_size
# 0        36      1   36    1     0.1    1.105171   10.000000
# 1       172      1  135    1    -0.1    0.904837    9.048374
# 2       334      1  161    1    -0.1    0.904837    8.187308
# 3       352      1   17    1     0.1    1.105171    9.048374
# 4       394      1   41    1     0.1    1.105171   10.000000
# ...     ...    ...  ...  ...     ...         ...         ...
# 1017  99391      1    4    1     0.1    1.105171    5.936501
# 1018  99574      1  182    1    -0.1    0.904837    5.371569
# 1019  99585      1   10    1     0.1    1.105171    5.936501
# 1020  99597      1   11    1     0.1    1.105171    6.560849
# 1021  99922      1  324    1    -0.1    0.904837    5.936501
#
# [1022 rows x 7 columns]

# %%
ind = pd.DataFrame({'index': np.array(range(N))})


new_df = ind.merge(df, on='index', how='left')

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(s, label='deltas')

# %%
x0 = 0.5; y0 = 0.5; k = 10
x_pia = np.arange(0,1,0.01)

fig, ax = plt.subplots(1, 1)
ax.plot(x_pia, scale_map(x_pia, k, x0, y0))

# %%
a = df['value'].shift().eq(0)
b = a.cumsum()
df['new'] = b.sub(b.mask(a).ffill().fillna(0)).astype(int)

# %%
BASE_BLOCK_SIZE = 10
s = BASE_BLOCK_SIZE*np.ones(N)

failure_rates = np.append(np.zeros(N-len(x)),x) 
deltas = failure_rates[1:] - failure_rates[:-1] 
deltas = np.exp(deltas)

block_sizes = np.array([s[k-1]*deltas[k] for k in range(2,N-1)])

for k in range(1,N-1):
    s[k] = s[k-1]*deltas[k]

fig, ax = plt.subplots(1, 1)
ax.plot(s, label='deltas')
